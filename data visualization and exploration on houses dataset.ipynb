# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
# %matplotlib inline

# %%
houses= pd.read_csv('housing_in_london_monthly_variables.csv')

# %%
houses.head()
# Out:
#          date            area  average_price       code  houses_sold  \
# 0  1995-01-01  city of london          91449  E09000001         17.0
# 1  1995-02-01  city of london          82203  E09000001          7.0
# 2  1995-03-01  city of london          79121  E09000001         14.0
# 3  1995-04-01  city of london          77101  E09000001          7.0
# 4  1995-05-01  city of london          84409  E09000001         10.0
#
#    no_of_crimes  borough_flag
# 0           NaN             1
# 1           NaN             1
# 2           NaN             1
# 3           NaN             1
# 4           NaN             1

# %%
housesmod= houses.drop('borough_flag', axis=1)

# %%
housesmod.head()
# Out:
#          date            area  average_price       code  houses_sold  \
# 0  1995-01-01  city of london          91449  E09000001         17.0
# 1  1995-02-01  city of london          82203  E09000001          7.0
# 2  1995-03-01  city of london          79121  E09000001         14.0
# 3  1995-04-01  city of london          77101  E09000001          7.0
# 4  1995-05-01  city of london          84409  E09000001         10.0
#
#    no_of_crimes
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN

# %%
housesmod['code'].nunique()
# Out:
# 45

# %%
housesmod['area'].nunique()
# Out:
# 45

# %%
housesmod['date'].nunique()
# Out:
# 301

# %%
housesmod.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13549 entries, 0 to 13548
# Data columns (total 6 columns):
# date             13549 non-null object
# area             13549 non-null object
# average_price    13549 non-null int64
# code             13549 non-null object
# houses_sold      13455 non-null float64
# no_of_crimes     7439 non-null float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 635.2+ KB

# %%
byarea= housesmod.groupby('area', axis =1)

# %%
byarea

# %%
housesmod['area'].unique()
# Out:
# array(['city of london', 'barking and dagenham', 'barnet', 'bexley',
#        'brent', 'bromley', 'camden', 'croydon', 'ealing', 'enfield',
#        'tower hamlets', 'greenwich', 'hackney', 'south east',
#        'hammersmith and fulham', 'haringey', 'harrow', 'havering',
#        'hillingdon', 'hounslow', 'islington', 'kensington and chelsea',
#        'kingston upon thames', 'lambeth', 'lewisham', 'merton', 'newham',
#        'redbridge', 'richmond upon thames', 'southwark', 'sutton',
#        'waltham forest', 'wandsworth', 'westminster', 'inner london',
#        'outer london', 'north east', 'north west', 'yorks and the humber',
#        'east midlands', 'west midlands', 'east of england', 'london',
#        'south west', 'england'], dtype=object)

# %%
housesmod[housesmod['area']=='city of london']
# Out:
#            date            area  average_price       code  houses_sold  \
# 0    1995-01-01  city of london          91449  E09000001         17.0
# 1    1995-02-01  city of london          82203  E09000001          7.0
# 2    1995-03-01  city of london          79121  E09000001         14.0
# 3    1995-04-01  city of london          77101  E09000001          7.0
# 4    1995-05-01  city of london          84409  E09000001         10.0
# 5    1995-06-01  city of london          94901  E09000001         17.0
# 6    1995-07-01  city of london         110128  E09000001         13.0
# 7    1995-08-01  city of london         112329  E09000001         14.0
# 8    1995-09-01  city of london         104473  E09000001         17.0
# 9    1995-10-01  city of london         108038  E09000001         14.0
# 10   1995-11-01  city of london         117636  E09000001         11.0
# 11   1995-12-01  city of london         127232  E09000001         18.0
# ...

# %%
cityoflon=housesmod[housesmod['area']=='city of london']

# %%
 novalue=housesmod[housesmod['area']=='city of london'].isnull()

# %%
sns.heatmap(novalue, cbar=False, cmap='coolwarm')

# %%
def replacenan(col):
    if pd.isnull(col):
        return 0
    else:
        return col

# %%
cityoflon['houses_sold']=cityoflon['houses_sold'].apply(replacenan)
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
novalue=housesmod[housesmod['area']=='city of london'].isnull()
sns.heatmap(cityoflon.isnull(), cbar=False, cmap='coolwarm')

# %%
cityoflon.loc[: , 'houses_sold']
# Out:
# 0      17.0
# 1       7.0
# 2      14.0
# 3       7.0
# 4      10.0
# 5      17.0
# 6      13.0
# 7      14.0
# 8      17.0
# 9      14.0
# 10     11.0
# 11     18.0
# 12     17.0
# 13     10.0
# 14     17.0
# 15     14.0
# 16     19.0
# 17     28.0
# 18     30.0
# 19     25.0
# 20     32.0
# 21     33.0
# 22     31.0
# 23     26.0
# 24     22.0
# 25     37.0
# 26     70.0
# 27     19.0
# 28     12.0
# 29     21.0
#        ...
# 271    21.0
# 272    29.0
# 273    17.0
# 274    14.0
# 275    20.0
# 276    34.0
# 277    27.0
# 278    19.0
# 279    14.0
# 280    19.0
# 281    87.0
# 282    32.0
# 283    22.0
# 284    40.0
# 285    30.0
# 286    31.0
# 287    37.0
# 288    10.0
# 289    10.0
# 290    14.0
# 291    20.0
# 292     7.0
# 293    16.0
# 294    13.0
# 295    17.0
# 296    11.0
# 297     4.0
# 298     5.0
# 299     0.0
# 300     0.0
# Name: houses_sold, Length: 301, dtype: float64

# %%
housesmod.drop('no_of_crimes', axis=1, inplace = True)

# %%
housesmod.head()
# Out:
#          date            area  average_price       code  houses_sold
# 0  1995-01-01  city of london          91449  E09000001         17.0
# 1  1995-02-01  city of london          82203  E09000001          7.0
# 2  1995-03-01  city of london          79121  E09000001         14.0
# 3  1995-04-01  city of london          77101  E09000001          7.0
# 4  1995-05-01  city of london          84409  E09000001         10.0

# %%
housesmod['houses_sold']=housesmod['houses_sold'].apply(replacenan)

# %%
sns.heatmap(housesmod.isnull(), cbar=False, cmap='viridis')

# %%
plt.figure(figsize=(12,8))
plt.scatter(x='average_price', y= 'houses_sold', data=cityoflon)

# %%
plt.figure(figsize=(12,10))
sns.distplot(cityoflon['average_price'], bins= 100)

# %%
sns.boxplot(y=cityoflon[cityoflon['average_price']<600000]['average_price'])

# %%
sns.boxplot(y=cityoflon[cityoflon['average_price']>600000]['average_price'])

# %%
import datetime

# %%
cityoflon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 301 entries, 0 to 300
# Data columns (total 6 columns):
# date             301 non-null object
# area             301 non-null object
# average_price    301 non-null int64
# code             301 non-null object
# houses_sold      301 non-null float64
# no_of_crimes     111 non-null float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 26.5+ KB

# %%
cityoflon.tail()
# Out:
#            date            area  average_price       code  houses_sold  \
# 296  2019-09-01  city of london         792034  E09000001         11.0
# 297  2019-10-01  city of london         827093  E09000001          4.0
# 298  2019-11-01  city of london         777610  E09000001          5.0
# 299  2019-12-01  city of london         734872  E09000001          0.0
# 300  2020-01-01  city of london         775309  E09000001          0.0
#
#      no_of_crimes
# 296           NaN
# 297           NaN
# 298           NaN
# 299           NaN
# 300           NaN

# %%
cityoflon['date']= pd.to_datetime(cityoflon['date'])
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
cityoflon.groupby(cityoflon['date'].dt.strftime('%m'))['houses_sold'].sum()
# Out:
# date
# 01    626.0
# 02    563.0
# 03    689.0
# 04    539.0
# 05    557.0
# 06    764.0
# 07    618.0
# 08    718.0
# 09    719.0
# 10    554.0
# 11    506.0
# 12    733.0
# Name: houses_sold, dtype: float64

# %%
cityoflon.groupby(cityoflon['date'].dt.strftime('%m'))['houses_sold'].mean().sort_values()
# Out:
# date
# 11    20.240000
# 04    21.560000
# 10    22.160000
# 05    22.280000
# 02    22.520000
# 01    24.076923
# 07    24.720000
# 03    27.560000
# 08    28.720000
# 09    28.760000
# 12    29.320000
# 06    30.560000
# Name: houses_sold, dtype: float64

# %%
cityoflon.groupby(cityoflon['date'].dt.strftime('%Y'))['houses_sold'].sum().sort_values()
# Out:
# date
# 2020      0.0
# 2019    127.0
# 2008    140.0
# 2009    157.0
# 1995    159.0
# 2016    172.0
# 2012    197.0
# 2017    219.0
# 2010    236.0
# 2011    255.0
# 2007    270.0
# 1996    282.0
# 2006    294.0
# 2005    303.0
# 2015    308.0
# 1997    315.0
# 2014    323.0
# 2001    367.0
# 2004    377.0
# 2002    392.0
# 2018    392.0
# 1998    424.0
# 2000    428.0
# 2013    433.0
# 2003    480.0
# 1999    536.0
# Name: houses_sold, dtype: float64

# %%
cityoflon.groupby(cityoflon['date'].dt.strftime('%Y'))['houses_sold'].mean().sort_values()
# Out:
# date
# 2020     0.000000
# 2019    10.583333
# 2008    11.666667
# 2009    13.083333
# 1995    13.250000
# 2016    14.333333
# 2012    16.416667
# 2017    18.250000
# 2010    19.666667
# 2011    21.250000
# 2007    22.500000
# 1996    23.500000
# 2006    24.500000
# 2005    25.250000
# 2015    25.666667
# 1997    26.250000
# 2014    26.916667
# 2001    30.583333
# 2004    31.416667
# 2002    32.666667
# 2018    32.666667
# 1998    35.333333
# 2000    35.666667
# 2013    36.083333
# 2003    40.000000
# 1999    44.666667
# Name: houses_sold, dtype: float64

# %%
cityoflon.groupby(cityoflon['date'].dt.strftime('%m'))['average_price'].mean()
# Out:
# date
# 01    429521.384615
# 02    414117.240000
# 03    413126.920000
# 04    412391.240000
# 05    417936.960000
# 06    425698.840000
# 07    425630.800000
# 08    427443.400000
# 09    424499.240000
# 10    428754.120000
# 11    431763.840000
# 12    436203.880000
# Name: average_price, dtype: float64

# %%
cityoflon.groupby(cityoflon['date'].dt.strftime('%Y'))['average_price'].mean().sort_values()
# Out:
# date
# 1995     99085.000000
# 1996    105651.166667
# 1997    117113.416667
# 1998    148031.916667
# 1999    171300.083333
# 2000    218679.000000
# 2001    250625.583333
# 2002    269632.250000
# 2003    270811.333333
# 2004    301032.833333
# 2005    311783.666667
# 2006    338518.583333
# 2009    383417.833333
# 2008    427296.833333
# 2007    433838.416667
# 2010    453662.833333
# 2011    463930.833333
# 2012    525327.500000
# 2013    570008.666667
# 2014    709385.416667
# 2015    760253.166667
# 2020    775309.000000
# 2018    784809.000000
# 2019    786983.083333
# 2016    818315.500000
# 2017    849790.166667
# Name: average_price, dtype: float64

# %%
sns.lmplot(x='average_price', y= 'houses_sold', data=cityoflon)

# %%
cityoflon_by_year=pd.pivot_table(data=cityoflon, index=cityoflon['date'].dt.strftime('%Y'), 
                                 columns=cityoflon['date'].dt.strftime('%m'),values='average_price'
                    )

# %%
cityoflon_by_year.head()
cityoflon_by_year.drop('2020', inplace=True)

# %%
plt.figure(figsize=(12,10))
sns.heatmap(cityoflon_by_year, linecolor='white', linewidths=1, cmap='coolwarm')

# %%
cityoflon_by_year.rename_axis('year', inplace=True)

# %%
cityoflon_by_year.rename_axis('month', axis=1, inplace=True)

# %%
sns.clustermap(cityoflon_by_year)

# %%
sns.clustermap(cityoflon_by_year, row_cluster=False,)

# %%
sns.pairplot(cityoflon_by_year)

# %%
cityoflon_by_month=pd.pivot_table(data=cityoflon, index=cityoflon['date'].dt.strftime('%m'), 
                                 columns=cityoflon['date'].dt.strftime('%Y'),values='average_price'
                    )

# %%
cityoflon_by_month.head()
# Out:
# year      1995      1996      1997      1998      1999      2000      2001  \
# month
# 01     91449.0  108999.0  116343.0  124382.0  149143.0  173738.0  284262.0
# 02     82203.0   93357.0  111142.0  143829.0  164545.0  174152.0  198137.0
# 03     79121.0   93707.0  107488.0  156508.0  174586.0  178339.0  189033.0
# 04     77101.0  120543.0  108480.0  163403.0  191157.0  183101.0  205494.0
# 05     84409.0  112050.0  115453.0  143625.0  191081.0  175041.0  223459.0
#
# year       2002      2003      2004    ...         2011      2012      2013  \
# month                                  ...
# 01     344239.0  261645.0  326913.0    ...     442413.0  525723.0  465451.0
# 02     284015.0  263992.0  301092.0    ...     504009.0  510537.0  499207.0
# 03     253697.0  291969.0  272731.0    ...     475353.0  527408.0  527874.0
# 04     245313.0  295174.0  269514.0    ...     516319.0  524290.0  590685.0
# 05     227281.0  284860.0  280062.0    ...     459477.0  573532.0  578037.0
#
# ...

# %%
cityoflon_by_month.rename_axis('month', inplace=True)
cityoflon_by_month.rename_axis('year', axis=1, inplace=True)

# %%
#sns.pairplot(cityoflon_by_month)

# %%
cityoflon.head()
# Out:
#         date            area  average_price       code  houses_sold  \
# 0 1995-01-01  city of london          91449  E09000001         17.0
# 1 1995-02-01  city of london          82203  E09000001          7.0
# 2 1995-03-01  city of london          79121  E09000001         14.0
# 3 1995-04-01  city of london          77101  E09000001          7.0
# 4 1995-05-01  city of london          84409  E09000001         10.0
#
#    no_of_crimes
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN

# %%
cityoflon_by_num=pd.pivot_table(data=cityoflon, index=cityoflon['date'].dt.strftime('%m'), 
                                 columns=cityoflon['date'].dt.strftime('%Y'),values='houses_sold')

# %%
cityoflon_by_num.head
# Out:
# date  1995  1996  1997  1998  1999  2000  2001  2002  2003  2004  ...   2011  \
# date                                                              ...
# 01    17.0  17.0  22.0  48.0  41.0  24.0  24.0  30.0  32.0  98.0  ...   16.0
# 02     7.0  10.0  37.0  43.0  31.0  55.0  37.0  12.0  20.0  16.0  ...   12.0
# 03    14.0  17.0  70.0  39.0  53.0  48.0  44.0  47.0  31.0  20.0  ...   19.0
# 04     7.0  14.0  19.0  28.0  28.0  58.0  38.0  31.0  30.0  25.0  ...   21.0
# 05    10.0  19.0  12.0  30.0  35.0  38.0  30.0  30.0  38.0  22.0  ...   28.0
#
# date  2012  2013  2014  2015  2016  2017  2018  2019  2020
# date
# 01    11.0  16.0  26.0  37.0  15.0  11.0  34.0  10.0   0.0
# 02    17.0  20.0  17.0  39.0  36.0   9.0  27.0  10.0   NaN
# 03     9.0  18.0  36.0  35.0  35.0  18.0  19.0  14.0   NaN
# 04    12.0  13.0  19.0  21.0   7.0  20.0  14.0  20.0   NaN
# 05    12.0  31.0  22.0  24.0   9.0  21.0  19.0   7.0   NaN
#
# [5 rows x 26 columns]

# %%
sns.pairplot(cityoflon_by_num)
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\numpy\core\_methods.py:29: RuntimeWarning: invalid value encountered in reduce
#   return umr_minimum(a, axis, None, out, keepdims)
# C:\Users\user\Anaconda3\lib\site-packages\numpy\core\_methods.py:26: RuntimeWarning: invalid value encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-132-e75bec0da797> in <module>()
# ----> 1 sns.pairplot(cityoflon_by_num)
#
# ~\Anaconda3\lib\site-packages\seaborn\axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, size, aspect, dropna, plot_kws, diag_kws, grid_kws)
#    2058     if grid.square_grid:
#    2059         if diag_kind == "hist":
# -> 2060             grid.map_diag(plt.hist, **diag_kws)
#    2061         elif diag_kind == "kde":
# ...

# %%
cityoflon_by_number=pd.pivot_table(data=cityoflon, index=cityoflon['date'].dt.strftime('%Y'), 
                                 columns=cityoflon['date'].dt.strftime('%m'),values='houses_sold')

# %%
cityoflon_by_number
# Out:
# date    01    02    03    04    05    06    07    08     09    10    11    12
# date
# 1995  17.0   7.0  14.0   7.0  10.0  17.0  13.0  14.0   17.0  14.0  11.0  18.0
# 1996  17.0  10.0  17.0  14.0  19.0  28.0  30.0  25.0   32.0  33.0  31.0  26.0
# 1997  22.0  37.0  70.0  19.0  12.0  21.0  26.0   9.0   22.0  22.0  18.0  37.0
# 1998  48.0  43.0  39.0  28.0  30.0  32.0  17.0  34.0   40.0  42.0  23.0  48.0
# 1999  41.0  31.0  53.0  28.0  35.0  63.0  42.0  58.0   30.0  29.0  29.0  97.0
# 2000  24.0  55.0  48.0  58.0  38.0  60.0  33.0  22.0   20.0  19.0  18.0  33.0
# 2001  24.0  37.0  44.0  38.0  30.0  36.0  40.0  30.0   30.0  26.0  15.0  17.0
# 2002  30.0  12.0  47.0  31.0  30.0  25.0  26.0  51.0   49.0  19.0  28.0  44.0
# 2003  32.0  20.0  31.0  30.0  38.0  84.0  48.0  46.0   38.0  33.0  42.0  38.0
# 2004  98.0  16.0  20.0  25.0  22.0  38.0  34.0  46.0   27.0  24.0  13.0  14.0
# 2005  17.0  18.0  18.0  32.0  20.0  33.0  29.0  26.0   37.0  14.0  29.0  30.0
# ...

# %%
cityoflon_by_number.rename_axis('year', inplace=True)
cityoflon_by_number.rename_axis('month', axis=1, inplace=True)

# %%
forexp=cityoflon_by_number.loc['2000']

# %%
forexp
# Out:
# month
# 01    24.0
# 02    55.0
# 03    48.0
# 04    58.0
# 05    38.0
# 06    60.0
# 07    33.0
# 08    22.0
# 09    20.0
# 10    19.0
# 11    18.0
# 12    33.0
# Name: 2000, dtype: float64

# %%
forexp.plot()

# %%
for i in cityoflon_by_number.index:
    forexpo=cityoflon_by_number.loc[i]
    forexpo.plot(label='i')
    plt.figure(figsize= (8,8))
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\matplotlib\pyplot.py:528: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
